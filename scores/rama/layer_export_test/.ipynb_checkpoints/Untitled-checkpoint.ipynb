# %%
from xml.dom import minidom

doc = minidom.parse('echoic_backup.svg')

# %%
svg = doc.getElementsByTagName('svg')

nodes = svg[0].childNodes

svgTag = '<svg xmlns="http://www.w3.org/2000/svg" width="5159.48087" height="4857.94043" viewBox="0 0 5159.48087 4857.94043">'



for n in nodes:
    if n.hasAttribute('id'):
        print( n.getAttribute('id') )
# Out:
# Layer_72_accord
# Layer_71_egtr
# Layer_70_sopr
# Layer_69_perc
# Layer_68_vc
# Layer_67b_hrn
# Layer_67_btuba
# Layer_66_tsax
# Layer_65_cl
# Layer_64b_arec
# Layer_64_ob
# Layer_63_fl
# Layer_62_vla
# Layer_61_vln
# Layer_60_accord
# Layer_59_egtr
# Layer_58_sopr
# Layer_57_perc
# Layer_56_vc
# Layer_55_trb
# Layer_54_trp
# Layer_53_cl
# Layer_52_trec
# Layer_51_fl
# Layer_50_vln
# Layer_49_vln
# Layer_48_accord
# Layer_47_egtr
# Layer_46_baritone
# Layer_45_perc
# Layer_44_db
# Layer_43_bsn
# Layer_42_asax
# Layer_41_cl
# Layer_40b_subrec
# Layer_40_brec
# Layer_39_fl
# Layer_38_vla
# Layer_37_vln
# Layer_36_accord
# Layer_35_egtr
# Layer_34_sopr
# Layer_33_perc
# Layer_32_vc
# Layer_31_trb
# Layer_30_tsax
# Layer_29_cl
# Layer_28_ob
# Layer_27_fl
# Layer_26_vln
# Layer_25_vln
# Layer_24_accord
# Layer_23_egtr
# Layer_22_sopr
# Layer_21_perc
# Layer_20_vc
# Layer_19_tuba
# Layer_18_trp
# Layer_17_cl
# Layer_16_srec
# Layer_15_fl
# Layer_14_vla
# Layer_13_vln
# Layer_12_accord
# Layer_11_egtr
# Layer_10_sopr
# Layer_9_perc
# Layer_8_vc
# Layer_7_trb
# Layer_6_asax
# Layer_5_cl
# Layer_4_fl
# Layer_3_fl
# Layer_2_vln
# Layer_1_vln
# clef-names
# count
# top_count
